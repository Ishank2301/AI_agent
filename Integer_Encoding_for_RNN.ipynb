# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishank2301/Comprehensive-ML-Handbook/blob/main/Integer_Encoding_for_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries:

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from keras.layers import Dense, SimpleRNN
from tensorflow.keras.preprocessing.text import Tokenizer

# %% [markdown]
# # Create the data:

# %%
docs = ['go india',
        'india india',
        'india india',
        'hip hip hurray',
        'jeetega bhai jeetega india jeetega',
        'bharat mata ki jai',
        'dhoni dhoni',
        'kohli kohli',
        'sachin sachin',
        'modi ji ki jai',
        'inquiklab jindabad']

# %%
tokenizer = Tokenizer(oov_token = '<nothing>')
tokenizer.fit_on_texts(docs)

# %%
tokenizer.word_index
# Out:
# {'<nothing>': 1,
#  'india': 2,
#  'jeetega': 3,
#  'hip': 4,
#  'ki': 5,
#  'jai': 6,
#  'dhoni': 7,
#  'kohli': 8,
#  'sachin': 9,
#  'go': 10,
#  'hurray': 11,
#  'bhai': 12,
#  'bharat': 13,
#  'mata': 14,
#  'modi': 15,
#  'ji': 16,
#  'inquiklab': 17,
#  'jindabad': 18}

# %%
tokenizer.document_count
# Out:
# 11

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('go', 1),
#              ('india', 6),
#              ('hip', 2),
#              ('hurray', 1),
#              ('jeetega', 3),
#              ('bhai', 1),
#              ('bharat', 1),
#              ('mata', 1),
#              ('ki', 2),
#              ('jai', 2),
#              ('dhoni', 2),
#              ('kohli', 2),
#              ('sachin', 2),
#              ('modi', 1),
#              ('ji', 1),
#              ('inquiklab', 1),
#              ('jindabad', 1)])

# %%
sequence = tokenizer.texts_to_sequences(docs)
sequence
# Out:
# [[10, 2],
#  [2, 2],
#  [2, 2],
#  [4, 4, 11],
#  [3, 12, 3, 2, 3],
#  [13, 14, 5, 6],
#  [7, 7],
#  [8, 8],
#  [9, 9],
#  [15, 16, 5, 6],
#  [17, 18]]

# %%
from keras.utils import pad_sequences
sequences = pad_sequences(sequence ,padding='post')
sequences
# Out:
# array([[10,  2,  0,  0,  0],
#        [ 2,  2,  0,  0,  0],
#        [ 2,  2,  0,  0,  0],
#        [ 4,  4, 11,  0,  0],
#        [ 3, 12,  3,  2,  3],
#        [13, 14,  5,  6,  0],
#        [ 7,  7,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [ 9,  9,  0,  0,  0],
#        [15, 16,  5,  6,  0],
#        [17, 18,  0,  0,  0]], dtype=int32)
